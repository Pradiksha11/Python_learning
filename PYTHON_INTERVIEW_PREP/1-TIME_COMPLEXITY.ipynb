# %%
# O(n) - Time Complexity
arr=[1,2,3,4,5]
def get_sum(arr):
    res = 0
    for i in arr:
        res+=i
    return res

print(get_sum(arr))
# Out:
# 15

# %%
# O(1) - Time Complexity
# For example i need to get the specific position value from a list
arr=[1,2,3,4,5,6,7,8,9,9876]#How long the dataset can be it will only get the one value and the time complesity will be same O(1)
print(arr[1])
# Out:
# 2
