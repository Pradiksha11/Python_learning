# %%
print("Hello Pradiksha")
# Out:
# Hello Pradiksha

# %%
print("Hello Pradiksha")
# Out:
# Hello Pradiksha

# %%
# My First Python Learning File
print("Hello! I'm learning Python with Git!")

# Simple math
a = 10
b = 5
print(f"{a} + {b} = {a + b}")

# My name
name = "Your Name"
print(f"My name is {name}")
# Out:
# Hello! I'm learning Python with Git!
# 10 + 5 = 15
# My name is Your Name
